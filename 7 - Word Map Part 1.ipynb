# %%
import pandas as pd
import json
from tqdm import tqdm
from pathlib import Path
cwd = Path('.')

# %%
'''Read in Raw Data: Comments.csv'''

comments_df= pd.read_csv(cwd/'output'/'comments.csv',usecols = [0,1], error_bad_lines=False)
videos_df=pd.read_csv(cwd/'output'/'videos.csv', usecols = [0,3], error_bad_lines=False)
comments_df=pd.merge(comments_df, videos_df, on='video_id',how='left')
comments_df.drop_duplicates(inplace=True)

comments_df.head(5)
# Out:
#        video_id                                       comment_text  \
# 0   XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️
# 14  XpVt6Z1Gjjo  I've been following you from the start of your...
# 28  XpVt6Z1Gjjo                 Say hi to Kong and maverick for me
# 42  XpVt6Z1Gjjo                                MY FAN . attendance
# 56  XpVt6Z1Gjjo                                         trending 😉
#
#     category_id
# 0            24
# 14           24
# 28           24
# 42           24
# 56           24

# %%
'''get training category ids'''
with open(cwd/'data_scraper'/'kaggle'/'GB_category_id.json') as json_file:
    gb_json = json.load(json_file)

id_to_category = {}
for i in gb_json['items']:
    category = i['snippet']['title']
    id = int(i['id'])
    id_to_category[id] = category
training_id = []
for i in id_to_category:
    training_id.append(i)

# %%
comments_df
# Out:
#              video_id                                       comment_text  \
# 0         XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️
# 14        XpVt6Z1Gjjo  I've been following you from the start of your...
# 28        XpVt6Z1Gjjo                 Say hi to Kong and maverick for me
# 42        XpVt6Z1Gjjo                                MY FAN . attendance
# 56        XpVt6Z1Gjjo                                         trending 😉
# 70        XpVt6Z1Gjjo                            #1 on trending AYYEEEEE
# 84        XpVt6Z1Gjjo                               The end though 😭👍🏻❤️
# 98        XpVt6Z1Gjjo                               #1 trending!!!!!!!!!
# 112       XpVt6Z1Gjjo                        Happy one year vlogaversary
# 126       XpVt6Z1Gjjo  You and your shit brother may have single hand...
# 140       XpVt6Z1Gjjo             There should be a mini Logan Paul too!
# 154       XpVt6Z1Gjjo  Dear Logan, I really wanna get your Merch but ...
# 168       XpVt6Z1Gjjo  Honestly Evan is so annoying. Like its not fun...
# 182       XpVt6Z1Gjjo                   Casey is still better then logan
# 196       XpVt6Z1Gjjo      aw geez rick this guy is the face of YouTube.
# 210       XpVt6Z1Gjjo                       He happy cause he in a movie
# 224       XpVt6Z1Gjjo  Ayyyyoooo Logang what up .  This was a hard vl...
# 238       XpVt6Z1Gjjo  Bro y didnt u give merch to johannes he is ur ...
# 252       XpVt6Z1Gjjo  It's been fun watching you grow. I'm at 42 day...
# 266       XpVt6Z1Gjjo             Made a lot of people hate youtube - GJ
# 280       XpVt6Z1Gjjo  NO HONEY NOOO can't believe he has almost 12 m...
# 294       XpVt6Z1Gjjo  Jake Paul is the fastest growing channel to hi...
# 308       XpVt6Z1Gjjo  lol PEWDIEPIE accidentally played song with wo...
# 322       XpVt6Z1Gjjo  You should do a prank that you broke  your pla...
# 336       XpVt6Z1Gjjo  I love Logan and Jake so much and thay are so ...
# 350       XpVt6Z1Gjjo                           #1 on Trending let's go.
# 364       XpVt6Z1Gjjo            Evan was being such a dick on this vlog
# 378       XpVt6Z1Gjjo  if you get allot of diss likes do you get on t...
# 392       XpVt6Z1Gjjo  Evan is a horrible human being he also looks s...
# 406       XpVt6Z1Gjjo  I love you so much I love to meet you But I li...
# ...               ...                                                ...
# 10590010  lLN1FwiqGwc  Pennywise 1990: We made balloons scary\nCritic...
# 10590024  lLN1FwiqGwc  I want to see Tim Curry portray the joker in a...
# 10590038  lLN1FwiqGwc  Critics got a point . \nI had no idea what I w...
# 10590052  lLN1FwiqGwc  How come CinemaSin can show several clips dire...
# 10590066  lLN1FwiqGwc  Doug, I think you are really funny... But I re...
# 10590080  lLN1FwiqGwc  Beating up tommy wiseu was the best part of th...
# 10590094  lLN1FwiqGwc       IT 2017 is better, IT 1990 was fucking trash
# 10590108  lLN1FwiqGwc  I like the new it movie better but I like the ...
# 10590136  lLN1FwiqGwc                                    Do the real one
# 10590150  lLN1FwiqGwc          End credits have a who's on first homage.
# 10590164  lLN1FwiqGwc  ...Was I the only one that liked the dancing s...
# 10590248  lLN1FwiqGwc                         24:28 absolutely killed me
# 10590262  lLN1FwiqGwc                              #IT vs Freddy Krueger
# 10590276  lLN1FwiqGwc                                25:09 \nOh F*ck No!
# 10590304  lLN1FwiqGwc                         kudos for the mtg cards :D
# 10590318  lLN1FwiqGwc                     You have a fiancé Tamara...? 😰
# 10590332  lLN1FwiqGwc                               Damn good episode! 😆
# 10590360  lLN1FwiqGwc                                               Yes!
# 10590374  lLN1FwiqGwc                                          I love it
# 10590388  lLN1FwiqGwc     Bloody boogers...\n-Nostalgia Critic, IT (old)
# 10590402  lLN1FwiqGwc  MEME ME! MEME ME! MEMEMEME MEME ME!\n\n😂😂😂😂😂😂😂...
# 10590416  lLN1FwiqGwc                   Tommy Wiseau is my greatest fear
# 10590430  lLN1FwiqGwc                                                 Hi
# 10590444  lLN1FwiqGwc                                    Who played bev?
# 10590458  lLN1FwiqGwc                                           The best
# 10590500  lLN1FwiqGwc                             *Gasp*\n*Gasp* \nGASP!
# 10590528  lLN1FwiqGwc                    Yeah, but does everybody float?
# 10590542  lLN1FwiqGwc                                That meme me dace 😂
# 10590556  lLN1FwiqGwc                     10:43 Is that Miles Upshur????
# 10590570  lLN1FwiqGwc                                WA-HA\nWA-HA\nWA-HA
#
#           category_id
# 0                  24
# 14                 24
# 28                 24
# 42                 24
# 56                 24
# 70                 24
# 84                 24
# 98                 24
# 112                24
# 126                24
# 140                24
# 154                24
# 168                24
# 182                24
# 196                24
# 210                24
# 224                24
# 238                24
# 252                24
# 266                24
# 280                24
# 294                24
# 308                24
# 322                24
# 336                24
# 350                24
# 364                24
# 378                24
# 392                24
# 406                24
# ...               ...
# 10590010           24
# 10590024           24
# 10590038           24
# 10590052           24
# 10590066           24
# 10590080           24
# 10590094           24
# 10590108           24
# 10590136           24
# 10590150           24
# 10590164           24
# 10590248           24
# 10590262           24
# 10590276           24
# 10590304           24
# 10590318           24
# 10590332           24
# 10590360           24
# 10590374           24
# 10590388           24
# 10590402           24
# 10590416           24
# 10590430           24
# 10590444           24
# 10590458           24
# 10590500           24
# 10590528           24
# 10590542           24
# 10590556           24
# 10590570           24
#
# [647262 rows x 3 columns]

# %%
comments_df['comment_text'] = comments_df['comment_text'].apply(str)

# %%
df = comments_df.groupby('category_id')['comment_text'].apply(list)

# %%
df = df.reset_index()

# %%
df = df.dropna()

# %%
df['comment_text'].dtype
# Out:
# dtype('O')

# %%
df['comments'] = df.apply(lambda row: " ".join(row['comment_text']), axis=1)

# %%
df['category'] = df['category_id'].map(id_to_category)
df['id'] = df['category_id']
df = df[['id', 'category', 'comments']]

# %%
df
# Out:
#     id              category  \
# 0    1      Film & Animation
# 1    2      Autos & Vehicles
# 2   10                 Music
# 3   15        Pets & Animals
# 4   17                Sports
# 5   19       Travel & Events
# 6   20                Gaming
# 7   22        People & Blogs
# 8   23                Comedy
# 9   24         Entertainment
# 10  25       News & Politics
# 11  26         Howto & Style
# 12  27             Education
# 13  28  Science & Technology
# 14  29                   NaN
# 15  43                 Shows
#
#                                              comments
# 0   I'm sure I speak for everyone when I say the w...
# 1   Imagine if Bernie was president,\n\n\n\n\n\n😃😃...
# 2   Trash and I like fergie but this shit is not g...
# 3   How does Mugumogu not collapse in a heap of la...
# 4   Wow I know these are just highlights but wow t...
# 5   Old Airport Road Hawker Center was AMAZING! Th...
# 6   Yellow fever Parker & (((Stone))) revealed who...
# 7   Love you Pewdiepie don't apologize your fine I...
# 8   Nothing's scarier than a guy replying to every...
# 9   Logan Paul it's yo big day ‼️‼️‼️ I've been fo...
# 10  I got hit by Hurricane Irma too, but it wasn't...
# 11  Did he just say chang-jangle?? What happened t...
# 12  Hey I hope you enjoy this new video! Some 370 ...
# 13  What if I wanna unlock my phone while in the b...
# 14  RIP Don. These two guys couldn't be more oppos...
# 15  I just squeeze the phone ask for pussy and wai...

# %%
df.drop([14,15],inplace=True)

# %%
df
# Out:
#     id              category  \
# 0    1      Film & Animation
# 1    2      Autos & Vehicles
# 2   10                 Music
# 3   15        Pets & Animals
# 4   17                Sports
# 5   19       Travel & Events
# 6   20                Gaming
# 7   22        People & Blogs
# 8   23                Comedy
# 9   24         Entertainment
# 10  25       News & Politics
# 11  26         Howto & Style
# 12  27             Education
# 13  28  Science & Technology
#
#                                              comments
# 0   I'm sure I speak for everyone when I say the w...
# 1   Imagine if Bernie was president,\n\n\n\n\n\n😃😃...
# 2   Trash and I like fergie but this shit is not g...
# 3   How does Mugumogu not collapse in a heap of la...
# 4   Wow I know these are just highlights but wow t...
# 5   Old Airport Road Hawker Center was AMAZING! Th...
# 6   Yellow fever Parker & (((Stone))) revealed who...
# 7   Love you Pewdiepie don't apologize your fine I...
# 8   Nothing's scarier than a guy replying to every...
# 9   Logan Paul it's yo big day ‼️‼️‼️ I've been fo...
# 10  I got hit by Hurricane Irma too, but it wasn't...
# 11  Did he just say chang-jangle?? What happened t...
# 12  Hey I hope you enjoy this new video! Some 370 ...
# 13  What if I wanna unlock my phone while in the b...

# %% [markdown]
# # Cleaning the text

# %%
import re
import string

df['comments'] = df['comments'].str.replace('[^\w\s#@/:%.,_-]', '', flags=re.UNICODE)
'''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers'''
def clean_text(text):
    text= text.lower()
    text = re.sub('\[.*?\]','',text)
    text = re.sub('[%s]'%re.escape(string.punctuation),'',text)
    text = re.sub('\w*\d\w*','',text)
    return text
clean1= lambda x: clean_text(x)


df_clean = pd.DataFrame (df['comments'].apply(clean1))
df_clean['category'] = df['category']
df_clean=df_clean[['category','comments']]

# %%
df_clean
# Out:
#                 category                                           comments
# 0       Film & Animation  im sure i speak for everyone when i say the wa...
# 1       Autos & Vehicles  imagine if bernie was presidentnnnnnn i used t...
# 2                  Music  trash and i like fergie but this shit is not g...
# 3         Pets & Animals  how does mugumogu not collapse in a heap of la...
# 4                 Sports  wow i know these are just highlights but wow t...
# 5        Travel & Events  old airport road hawker center was amazing tha...
# 6                 Gaming  yellow fever parker  stone revealed who they r...
# 7         People & Blogs  love you pewdiepie dont apologize your fine i ...
# 8                 Comedy  nothings scarier than a guy replying to every ...
# 9          Entertainment  logan paul its yo big day  ive been following ...
# 10       News & Politics  i got hit by hurricane irma too but it wasnt a...
# 11         Howto & Style  did he just say changjangle what happened to w...
# 12             Education  hey i hope you enjoy this new video some  of y...
# 13  Science & Technology  what if i wanna unlock my phone while in the b...

# %%
'''Produce a document term matrix of words for each category '''
from sklearn.feature_extraction.text import CountVectorizer

cv=CountVectorizer(stop_words = 'english')
data_cv = cv.fit_transform(df_clean.comments)
data_dtm = pd.DataFrame(data_cv.toarray(),columns=cv.get_feature_names())
data_dtm['category'] = df_clean['category']
data_dtm = data_dtm.set_index('category')
data_dtm
# Out:
#                       aa  aaa  aaaa  aaaaa  aaaaaa  aaaaaaa  aaaaaaaa  \
# category
# Film & Animation       0    3     0      1       2        0         0
# Autos & Vehicles       1    2     0      0       0        0         0
# Music                 82   50    17     15      10        9        10
# Pets & Animals         1    0     0      1       0        0         0
# Sports                 4    1     1      0       0        0         0
# Travel & Events        0    0     0      0       0        0         0
# Gaming                 4   17     0      1       0        0         0
# People & Blogs         5    2     6      2       2        3         2
# Comedy                 5    7     3      2       2        1         3
# Entertainment         13   10     6      2       5        5         3
# News & Politics        1    1     0      0       0        0         0
# Howto & Style          1    1     2      0       1        1         0
# Education              3    1     0      0       0        3         0
# Science & Technology   3    2     0      0       1        0         0
#
#                       aaaaaaaaa  aaaaaaaaaa  aaaaaaaaaaa  ...  𝗦𝗟𝗜𝗖𝗘  𝘾𝙝𝙚𝙘𝙠  \
# category                                                  ...
# Film & Animation              0           1            0  ...      0      0
# Autos & Vehicles              0           0            0  ...      0      0
# Music                         1           5            5  ...      0      0
# Pets & Animals                0           1            0  ...      0      0
# Sports                        0           0            0  ...      0      0
# Travel & Events               0           0            0  ...      0      0
# Gaming                        0           0            0  ...      0      0
# People & Blogs                0           0            0  ...      0      0
# Comedy                        1           1            0  ...      1      0
# Entertainment                 3           1            2  ...      0      0
# News & Politics               0           0            0  ...      0      0
# Howto & Style                 0           0            0  ...      0      1
# Education                     0           0            0  ...      0      0
# Science & Technology          1           0            0  ...      0      0
#
#                       𝙊𝙪𝙧  𝙘𝙤𝙤𝙡  𝙙𝙚𝙖𝙡𝙨  𝙙𝙞𝙨𝙘𝙤𝙪𝙣𝙩  𝙤𝙪𝙩  𝙨𝙝𝙞𝙥𝙨  𝙬𝙖𝙧𝙚𝙝𝙤𝙪𝙨𝙚  𝙬𝙞𝙩𝙝
# category
# Film & Animation        0     0      0         0    0      0          0     0
# Autos & Vehicles        0     0      0         0    0      0          0     0
# Music                   0     0      0         0    0      0          0     0
# Pets & Animals          0     0      0         0    0      0          0     0
# Sports                  0     0      0         0    0      0          0     0
# Travel & Events         0     0      0         0    0      0          0     0
# Gaming                  0     0      0         0    0      0          0     0
# People & Blogs          0     0      0         0    0      0          0     0
# Comedy                  0     0      0         0    0      0          0     0
# Entertainment           0     0      0         0    0      0          0     0
# News & Politics         0     0      0         0    0      0          0     0
# Howto & Style           1     1      1         1    1      1          1     1
# Education               0     0      0         0    0      0          0     0
# Science & Technology    0     0      0         0    0      0          0     0
#
# [14 rows x 256217 columns]

# %% [markdown]
# # Let's visualize the results

# %%
# NUMBER 1 : WORD MAPPP
data=data_dtm.transpose()
data.head()
# Out:
# category  Film & Animation  Autos & Vehicles  Music  Pets & Animals  Sports  \
# aa                       0                 1     82               1       4
# aaa                      3                 2     50               0       1
# aaaa                     0                 0     17               0       1
# aaaaa                    1                 0     15               1       0
# aaaaaa                   2                 0     10               0       0
#
# category  Travel & Events  Gaming  People & Blogs  Comedy  Entertainment  \
# aa                      0       4               5       5             13
# aaa                     0      17               2       7             10
# aaaa                    0       0               6       3              6
# aaaaa                   0       1               2       2              2
# aaaaaa                  0       0               2       2              5
#
# category  News & Politics  Howto & Style  Education  Science & Technology
# aa                      1              1          3                     3
# aaa                     1              1          1                     2
# aaaa                    0              2          0                     0
# aaaaa                   0              0          0                     0
# aaaaaa                  0              1          0                     1

# %%
'''Create dictionary to count top 30 words in each category'''
top_dict = {}
for c in data.columns:
    try:
        top = data[c].sort_values(ascending = False).head(30)
        top_dict[c] = list(zip(top.index, top.values))
    except:
        continue
top_dict
# Out:
# {'Film & Animation': [('like', 2849),
#   ('movie', 2686),
#   ('just', 2069),
#   ('im', 1657),
#   ('love', 1396),
#   ('video', 1243),
#   ('dont', 1176),
#   ('good', 1141),
#   ('know', 1021),
#   ('looks', 996),
#   ('really', 989),
#   ('people', 952),
#   ('make', 920),
#   ('time', 869),
#   ('say', 867),
#   ('think', 856),
#   ('trailer', 843),
#   ('did', 819),
#   ('great', 730),
#   ('want', 725),
#   ('watch', 677),
#   ('rick', 654),
#   ('new', 622),
#   ('lol', 614),
#   ('wrong', 606),
#   ('got', 592),
#   ('thats', 552),
#   ('going', 538),
#   ('way', 519),
#   ('film', 517)],
#  'Autos & Vehicles': [('car', 648),
#   ('like', 481),
#   ('video', 398),
#   ('just', 371),
#   ('make', 281),
#   ('cars', 205),
#   ('good', 200),
#   ('im', 199),
#   ('engine', 191),
#   ('love', 190),
#   ('dont', 183),
#   ('really', 160),
#   ('know', 159),
#   ('great', 155),
#   ('time', 154),
#   ('pilot', 148),
#   ('videos', 145),
#   ('way', 143),
#   ('thats', 140),
#   ('work', 138),
#   ('did', 136),
#   ('going', 136),
#   ('think', 135),
#   ('new', 125),
#   ('people', 125),
#   ('does', 123),
#   ('looks', 123),
#   ('got', 118),
#   ('use', 116),
#   ('shit', 112)],
#  'Music': [('love', 16111),
#   ('song', 14212),
#   ('like', 10738),
#   ('im', 7376),
#   ('just', 6750),
#   ('video', 5834),
#   ('music', 5349),
#   ('good', 5236),
#   ('dont', 4056),
#   ('amazing', 3776),
#   ('know', 3193),
#   ('beautiful', 3155),
#   ('great', 3141),
#   ('really', 3001),
#   ('best', 2833),
#   ('new', 2606),
#   ('voice', 2589),
#   ('time', 2581),
#   ('got', 2385),
#   ('que', 2254),
#   ('songs', 2139),
#   ('make', 2105),
#   ('think', 2073),
#   ('people', 2038),
#   ('album', 2027),
#   ('better', 1929),
#   ('omg', 1925),
#   ('fuck', 1918),
#   ('way', 1898),
#   ('shit', 1869)],
#  'Pets & Animals': [('like', 692),
#   ('love', 550),
#   ('just', 426),
#   ('cat', 401),
#   ('video', 397),
#   ('coyote', 338),
#   ('im', 322),
#   ('dog', 246),
#   ('dont', 219),
#   ('spider', 202),
#   ('cute', 199),
#   ('know', 195),
#   ('amazing', 187),
#   ('beautiful', 184),
#   ('cats', 182),
#   ('good', 181),
#   ('really', 181),
#   ('spiders', 177),
#   ('got', 175),
#   ('animals', 168),
#   ('people', 166),
#   ('great', 165),
#   ('time', 163),
#   ('fish', 155),
#   ('make', 153),
#   ('videos', 151),
#   ('dogs', 148),
#   ('think', 147),
#   ('thats', 145),
#   ('cool', 140)],
#  'Sports': [('like', 2655),
#   ('just', 1754),
#   ('good', 1341),
#   ('dont', 1231),
#   ('game', 1097),
#   ('im', 1053),
#   ('love', 1053),
#   ('team', 1005),
#   ('man', 990),
#   ('people', 987),
#   ('video', 951),
#   ('best', 939),
#   ('hes', 937),
#   ('ik', 918),
#   ('lol', 915),
#   ('great', 880),
#   ('time', 799),
#   ('did', 798),
#   ('que', 794),
#   ('know', 784),
#   ('got', 783),
#   ('make', 730),
#   ('fan', 710),
#   ('better', 707),
#   ('think', 706),
#   ('really', 702),
#   ('fuck', 688),
#   ('win', 685),
#   ('guy', 682),
#   ('shit', 676)],
#  'Travel & Events': [('food', 296),
#   ('like', 290),
#   ('love', 262),
#   ('video', 213),
#   ('im', 183),
#   ('just', 177),
#   ('videos', 155),
#   ('good', 135),
#   ('eat', 123),
#   ('people', 111),
#   ('looks', 109),
#   ('know', 107),
#   ('lol', 102),
#   ('amazing', 96),
#   ('dont', 95),
#   ('really', 93),
#   ('time', 92),
#   ('great', 92),
#   ('guys', 89),
#   ('vegan', 84),
#   ('watching', 81),
#   ('make', 80),
#   ('want', 77),
#   ('think', 71),
#   ('thats', 70),
#   ('nice', 69),
#   ('try', 68),
#   ('apartment', 65),
#   ('live', 65),
#   ('place', 63)],
#  'Gaming': [('game', 2213),
#   ('like', 1608),
#   ('just', 1159),
#   ('im', 860),
#   ('dont', 804),
#   ('games', 720),
#   ('good', 662),
#   ('video', 659),
#   ('wipesnnever', 625),
#   ('people', 603),
#   ('love', 580),
#   ('really', 556),
#   ('time', 553),
#   ('make', 521),
#   ('play', 509),
#   ('looks', 472),
#   ('know', 440),
#   ('great', 428),
#   ('think', 420),
#   ('new', 387),
#   ('want', 385),
#   ('did', 370),
#   ('going', 351),
#   ('best', 346),
#   ('mario', 344),
#   ('got', 339),
#   ('wait', 338),
#   ('thats', 326),
#   ('need', 326),
#   ('better', 326)],
#  'People & Blogs': [('like', 8157),
#   ('love', 7586),
#   ('just', 6644),
#   ('im', 6471),
#   ('video', 4968),
#   ('dont', 4028),
#   ('really', 3672),
#   ('people', 3653),
#   ('know', 3301),
#   ('good', 2822),
#   ('think', 2634),
#   ('make', 2576),
#   ('time', 2519),
#   ('look', 2328),
#   ('soap', 2228),
#   ('did', 2102),
#   ('videos', 2049),
#   ('want', 2044),
#   ('youre', 1989),
#   ('lol', 1946),
#   ('got', 1931),
#   ('ive', 1868),
#   ('way', 1761),
#   ('feel', 1694),
#   ('going', 1692),
#   ('great', 1687),
#   ('looks', 1672),
#   ('guys', 1659),
#   ('say', 1633),
#   ('thank', 1575)],
#  'Comedy': [('like', 5962),
#   ('just', 4340),
#   ('love', 4074),
#   ('im', 3526),
#   ('video', 3283),
#   ('people', 2909),
#   ('dont', 2805),
#   ('good', 2088),
#   ('lol', 2003),
#   ('know', 1946),
#   ('make', 1940),
#   ('funny', 1867),
#   ('really', 1774),
#   ('time', 1688),
#   ('did', 1676),
#   ('think', 1463),
#   ('want', 1368),
#   ('got', 1294),
#   ('look', 1265),
#   ('guys', 1248),
#   ('trump', 1241),
#   ('best', 1212),
#   ('thats', 1191),
#   ('videos', 1173),
#   ('watch', 1114),
#   ('right', 1102),
#   ('say', 1086),
#   ('great', 1070),
#   ('looks', 1070),
#   ('omg', 1056)],
#  'Entertainment': [('like', 13661),
#   ('just', 9726),
#   ('love', 9152),
#   ('im', 8057),
#   ('dont', 5961),
#   ('people', 5692),
#   ('video', 4945),
#   ('good', 4862),
#   ('know', 4439),
#   ('make', 4349),
#   ('really', 4130),
#   ('movie', 3893),
#   ('think', 3721),
#   ('best', 3611),
#   ('did', 3576),
#   ('time', 3390),
#   ('looks', 3201),
#   ('lol', 3159),
#   ('got', 2852),
#   ('look', 2841),
#   ('great', 2826),
#   ('shit', 2801),
#   ('want', 2768),
#   ('watch', 2665),
#   ('way', 2612),
#   ('thats', 2571),
#   ('going', 2522),
#   ('man', 2516),
#   ('fuck', 2437),
#   ('amazing', 2413)],
#  'News & Politics': [('people', 4006),
#   ('like', 3349),
#   ('just', 2851),
#   ('dont', 2178),
#   ('trump', 1745),
#   ('im', 1427),
#   ('world', 1346),
#   ('know', 1310),
#   ('video', 1185),
#   ('think', 1154),
#   ('did', 1121),
#   ('white', 1088),
#   ('right', 1058),
#   ('good', 1053),
#   ('make', 998),
#   ('want', 956),
#   ('time', 947),
#   ('black', 938),
#   ('going', 930),
#   ('really', 922),
#   ('thats', 913),
#   ('man', 909),
#   ('country', 883),
#   ('way', 873),
#   ('god', 873),
#   ('guy', 849),
#   ('say', 835),
#   ('news', 822),
#   ('love', 810),
#   ('need', 803)],
#  'Howto & Style': [('love', 14245),
#   ('like', 8246),
#   ('im', 6428),
#   ('just', 5760),
#   ('video', 5515),
#   ('look', 5204),
#   ('make', 4303),
#   ('really', 3348),
#   ('dont', 3265),
#   ('videos', 3006),
#   ('looks', 2941),
#   ('makeup', 2809),
#   ('know', 2667),
#   ('good', 2659),
#   ('amazing', 2610),
#   ('youre', 2492),
#   ('beautiful', 2476),
#   ('think', 2253),
#   ('omg', 2160),
#   ('lol', 2146),
#   ('great', 2131),
#   ('time', 2096),
#   ('hair', 2038),
#   ('cake', 2008),
#   ('did', 1953),
#   ('want', 1860),
#   ('need', 1839),
#   ('ive', 1818),
#   ('girl', 1748),
#   ('thank', 1742)],
#  'Education': [('like', 1930),
#   ('video', 1779),
#   ('just', 1779),
#   ('people', 1321),
#   ('dont', 1265),
#   ('im', 1246),
#   ('make', 895),
#   ('simulation', 884),
#   ('know', 831),
#   ('time', 779),
#   ('great', 775),
#   ('think', 769),
#   ('good', 742),
#   ('really', 695),
#   ('life', 676),
#   ('love', 664),
#   ('want', 603),
#   ('world', 540),
#   ('way', 537),
#   ('live', 521),
#   ('thats', 518),
#   ('did', 510),
#   ('videos', 477),
#   ('need', 468),
#   ('use', 443),
#   ('thing', 437),
#   ('years', 423),
#   ('inside', 414),
#   ('say', 400),
#   ('work', 397)],
#  'Science & Technology': [('like', 2964),
#   ('just', 2639),
#   ('video', 2165),
#   ('iphone', 2119),
#   ('im', 1587),
#   ('phone', 1550),
#   ('dont', 1491),
#   ('make', 1235),
#   ('people', 1206),
#   ('apple', 1079),
#   ('love', 1055),
#   ('know', 1010),
#   ('think', 985),
#   ('good', 956),
#   ('time', 938),
#   ('really', 937),
#   ('use', 930),
#   ('way', 825),
#   ('want', 821),
#   ('great', 817),
#   ('new', 811),
#   ('need', 790),
#   ('does', 787),
#   ('thats', 711),
#   ('going', 704),
#   ('google', 701),
#   ('did', 691),
#   ('better', 660),
#   ('lol', 648),
#   ('looks', 627)]}

# %%
words = []

for category in data.columns:
    try:
        top = [word for (word, count) in top_dict[category]]
    except:
        # some categories has less than 30 top words
        pass
    for t in top:
        words.append(t)
words
# Out:
# ['like',
#  'movie',
#  'just',
#  'im',
#  'love',
#  'video',
#  'dont',
#  'good',
#  'know',
#  'looks',
#  'really',
#  'people',
#  'make',
#  'time',
#  'say',
#  'think',
#  'trailer',
#  'did',
#  'great',
#  'want',
#  'watch',
#  'rick',
#  'new',
#  'lol',
#  'wrong',
#  'got',
#  'thats',
#  'going',
#  'way',
#  'film',
#  'car',
#  'like',
#  'video',
#  'just',
#  'make',
#  'cars',
#  'good',
#  'im',
#  'engine',
#  'love',
#  'dont',
#  'really',
#  'know',
#  'great',
#  'time',
#  'pilot',
#  'videos',
#  'way',
#  'thats',
#  'work',
#  'did',
#  'going',
#  'think',
#  'new',
#  'people',
#  'does',
#  'looks',
#  'got',
#  'use',
#  'shit',
#  'love',
#  'song',
#  'like',
#  'im',
#  'just',
#  'video',
#  'music',
#  'good',
#  'dont',
#  'amazing',
#  'know',
#  'beautiful',
#  'great',
#  'really',
#  'best',
#  'new',
#  'voice',
#  'time',
#  'got',
#  'que',
#  'songs',
#  'make',
#  'think',
#  'people',
#  'album',
#  'better',
#  'omg',
#  'fuck',
#  'way',
#  'shit',
#  'like',
#  'love',
#  'just',
#  'cat',
#  'video',
#  'coyote',
#  'im',
#  'dog',
#  'dont',
#  'spider',
#  'cute',
#  'know',
#  'amazing',
#  'beautiful',
#  'cats',
#  'good',
#  'really',
#  'spiders',
#  'got',
#  'animals',
#  'people',
#  'great',
#  'time',
#  'fish',
#  'make',
#  'videos',
#  'dogs',
#  'think',
#  'thats',
#  'cool',
#  'like',
#  'just',
#  'good',
#  'dont',
#  'game',
#  'im',
#  'love',
#  'team',
#  'man',
#  'people',
#  'video',
#  'best',
#  'hes',
#  'ik',
#  'lol',
#  'great',
#  'time',
#  'did',
#  'que',
#  'know',
#  'got',
#  'make',
#  'fan',
#  'better',
#  'think',
#  'really',
#  'fuck',
#  'win',
#  'guy',
#  'shit',
#  'food',
#  'like',
#  'love',
#  'video',
#  'im',
#  'just',
#  'videos',
#  'good',
#  'eat',
#  'people',
#  'looks',
#  'know',
#  'lol',
#  'amazing',
#  'dont',
#  'really',
#  'time',
#  'great',
#  'guys',
#  'vegan',
#  'watching',
#  'make',
#  'want',
#  'think',
#  'thats',
#  'nice',
#  'try',
#  'apartment',
#  'live',
#  'place',
#  'game',
#  'like',
#  'just',
#  'im',
#  'dont',
#  'games',
#  'good',
#  'video',
#  'wipesnnever',
#  'people',
#  'love',
#  'really',
#  'time',
#  'make',
#  'play',
#  'looks',
#  'know',
#  'great',
#  'think',
#  'new',
#  'want',
#  'did',
#  'going',
#  'best',
#  'mario',
#  'got',
#  'wait',
#  'thats',
#  'need',
#  'better',
#  'like',
#  'love',
#  'just',
#  'im',
#  'video',
#  'dont',
#  'really',
#  'people',
#  'know',
#  'good',
#  'think',
#  'make',
#  'time',
#  'look',
#  'soap',
#  'did',
#  'videos',
#  'want',
#  'youre',
#  'lol',
#  'got',
#  'ive',
#  'way',
#  'feel',
#  'going',
#  'great',
#  'looks',
#  'guys',
#  'say',
#  'thank',
#  'like',
#  'just',
#  'love',
#  'im',
#  'video',
#  'people',
#  'dont',
#  'good',
#  'lol',
#  'know',
#  'make',
#  'funny',
#  'really',
#  'time',
#  'did',
#  'think',
#  'want',
#  'got',
#  'look',
#  'guys',
#  'trump',
#  'best',
#  'thats',
#  'videos',
#  'watch',
#  'right',
#  'say',
#  'great',
#  'looks',
#  'omg',
#  'like',
#  'just',
#  'love',
#  'im',
#  'dont',
#  'people',
#  'video',
#  'good',
#  'know',
#  'make',
#  'really',
#  'movie',
#  'think',
#  'best',
#  'did',
#  'time',
#  'looks',
#  'lol',
#  'got',
#  'look',
#  'great',
#  'shit',
#  'want',
#  'watch',
#  'way',
#  'thats',
#  'going',
#  'man',
#  'fuck',
#  'amazing',
#  'people',
#  'like',
#  'just',
#  'dont',
#  'trump',
#  'im',
#  'world',
#  'know',
#  'video',
#  'think',
#  'did',
#  'white',
#  'right',
#  'good',
#  'make',
#  'want',
#  'time',
#  'black',
#  'going',
#  'really',
#  'thats',
#  'man',
#  'country',
#  'way',
#  'god',
#  'guy',
#  'say',
#  'news',
#  'love',
#  'need',
#  'love',
#  'like',
#  'im',
#  'just',
#  'video',
#  'look',
#  'make',
#  'really',
#  'dont',
#  'videos',
#  'looks',
#  'makeup',
#  'know',
#  'good',
#  'amazing',
#  'youre',
#  'beautiful',
#  'think',
#  'omg',
#  'lol',
#  'great',
#  'time',
#  'hair',
#  'cake',
#  'did',
#  'want',
#  'need',
#  'ive',
#  'girl',
#  'thank',
#  'like',
#  'video',
#  'just',
#  'people',
#  'dont',
#  'im',
#  'make',
#  'simulation',
#  'know',
#  'time',
#  'great',
#  'think',
#  'good',
#  'really',
#  'life',
#  'love',
#  'want',
#  'world',
#  'way',
#  'live',
#  'thats',
#  'did',
#  'videos',
#  'need',
#  'use',
#  'thing',
#  'years',
#  'inside',
#  'say',
#  'work',
#  'like',
#  'just',
#  'video',
#  'iphone',
#  'im',
#  'phone',
#  'dont',
#  'make',
#  'people',
#  'apple',
#  'love',
#  'know',
#  'think',
#  'good',
#  'time',
#  'really',
#  'use',
#  'way',
#  'want',
#  'great',
#  'new',
#  'need',
#  'does',
#  'thats',
#  'going',
#  'google',
#  'did',
#  'better',
#  'lol',
#  'looks']

# %%
'''Show words which appear most commonly across categories'''

from collections import Counter
Counter(words).most_common()
# Out:
# [('like', 14),
#  ('just', 14),
#  ('im', 14),
#  ('love', 14),
#  ('video', 14),
#  ('dont', 14),
#  ('good', 14),
#  ('know', 14),
#  ('really', 14),
#  ('make', 14),
#  ('time', 14),
#  ('think', 14),
#  ('people', 13),
#  ('great', 13),
#  ('did', 11),
#  ('want', 10),
#  ('thats', 10),
#  ('looks', 9),
#  ('got', 9),
#  ('lol', 8),
#  ('way', 8),
#  ('going', 7),
#  ('videos', 7),
#  ('say', 5),
#  ('new', 5),
#  ('amazing', 5),
#  ('best', 5),
#  ('need', 5),
#  ('shit', 4),
#  ('better', 4),
#  ('look', 4),
#  ('watch', 3),
#  ('use', 3),
#  ('beautiful', 3),
#  ('omg', 3),
#  ('fuck', 3),
#  ('man', 3),
#  ('guys', 3),
#  ('movie', 2),
#  ('work', 2),
#  ('does', 2),
#  ('que', 2),
#  ('game', 2),
#  ('guy', 2),
#  ('live', 2),
#  ('youre', 2),
#  ('ive', 2),
#  ('thank', 2),
#  ('trump', 2),
#  ('right', 2),
#  ('world', 2),
#  ('trailer', 1),
#  ('rick', 1),
#  ('wrong', 1),
#  ('film', 1),
#  ('car', 1),
#  ('cars', 1),
#  ('engine', 1),
#  ('pilot', 1),
#  ('song', 1),
#  ('music', 1),
#  ('voice', 1),
#  ('songs', 1),
#  ('album', 1),
#  ('cat', 1),
#  ('coyote', 1),
#  ('dog', 1),
#  ('spider', 1),
#  ('cute', 1),
#  ('cats', 1),
#  ('spiders', 1),
#  ('animals', 1),
#  ('fish', 1),
#  ('dogs', 1),
#  ('cool', 1),
#  ('team', 1),
#  ('hes', 1),
#  ('ik', 1),
#  ('fan', 1),
#  ('win', 1),
#  ('food', 1),
#  ('eat', 1),
#  ('vegan', 1),
#  ('watching', 1),
#  ('nice', 1),
#  ('try', 1),
#  ('apartment', 1),
#  ('place', 1),
#  ('games', 1),
#  ('wipesnnever', 1),
#  ('play', 1),
#  ('mario', 1),
#  ('wait', 1),
#  ('soap', 1),
#  ('feel', 1),
#  ('funny', 1),
#  ('white', 1),
#  ('black', 1),
#  ('country', 1),
#  ('god', 1),
#  ('news', 1),
#  ('makeup', 1),
#  ('hair', 1),
#  ('cake', 1),
#  ('girl', 1),
#  ('simulation', 1),
#  ('life', 1),
#  ('thing', 1),
#  ('years', 1),
#  ('inside', 1),
#  ('iphone', 1),
#  ('phone', 1),
#  ('apple', 1),
#  ('google', 1)]

# %%
'''Make stop words include those words which appear most commonly in over half the categories'''

add_stop_words = [word for word, count in Counter(words).most_common() if count > 2]
add_stop_words
# Out:
# ['like',
#  'just',
#  'im',
#  'love',
#  'video',
#  'dont',
#  'good',
#  'know',
#  'really',
#  'make',
#  'time',
#  'think',
#  'people',
#  'great',
#  'did',
#  'want',
#  'thats',
#  'looks',
#  'got',
#  'lol',
#  'way',
#  'going',
#  'videos',
#  'say',
#  'new',
#  'amazing',
#  'best',
#  'need',
#  'shit',
#  'better',
#  'look',
#  'watch',
#  'use',
#  'beautiful',
#  'omg',
#  'fuck',
#  'man',
#  'guys']

# %%
'''Re-construct the dtm with new stop words'''

from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer

stop_words = text.ENGLISH_STOP_WORDS.union (add_stop_words)
cv=CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(df_clean.comments)
data_stop = pd.DataFrame (data_cv.toarray(),columns=cv.get_feature_names())

data_stop['category']=df['category']
data_stop = data_stop.set_index('category')
data_stop.head()
# Out:
#                   aa  aaa  aaaa  aaaaa  aaaaaa  aaaaaaa  aaaaaaaa  aaaaaaaaa  \
# category
# Film & Animation   0    3     0      1       2        0         0          0
# Autos & Vehicles   1    2     0      0       0        0         0          0
# Music             82   50    17     15      10        9        10          1
# Pets & Animals     1    0     0      1       0        0         0          0
# Sports             4    1     1      0       0        0         0          0
#
#                   aaaaaaaaaa  aaaaaaaaaaa  ...  𝗦𝗟𝗜𝗖𝗘  𝘾𝙝𝙚𝙘𝙠  𝙊𝙪𝙧  𝙘𝙤𝙤𝙡  \
# category                                   ...
# Film & Animation           1            0  ...      0      0    0     0
# Autos & Vehicles           0            0  ...      0      0    0     0
# Music                      5            5  ...      0      0    0     0
# Pets & Animals             1            0  ...      0      0    0     0
# Sports                     0            0  ...      0      0    0     0
#
#                   𝙙𝙚𝙖𝙡𝙨  𝙙𝙞𝙨𝙘𝙤𝙪𝙣𝙩  𝙤𝙪𝙩  𝙨𝙝𝙞𝙥𝙨  𝙬𝙖𝙧𝙚𝙝𝙤𝙪𝙨𝙚  𝙬𝙞𝙩𝙝
# category
# Film & Animation      0         0    0      0          0     0
# Autos & Vehicles      0         0    0      0          0     0
# Music                 0         0    0      0          0     0
# Pets & Animals        0         0    0      0          0     0
# Sports                0         0    0      0          0     0
#
# [5 rows x 256179 columns]

# %%
from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42,collocations= False)


import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [20, 10]

cat_names = df_clean['category'].tolist()

df_clean.set_index('category',inplace=True)
df_clean.head()
# Out:
#                                                            comments
# category
# Film & Animation  im sure i speak for everyone when i say the wa...
# Autos & Vehicles  imagine if bernie was presidentnnnnnn i used t...
# Music             trash and i like fergie but this shit is not g...
# Pets & Animals    how does mugumogu not collapse in a heap of la...
# Sports            wow i know these are just highlights but wow t...

# %%
for index, cat in enumerate(data.columns):
    try:
        wc.generate(df_clean.comments[cat])
    except:
        pass
    fig = plt.gcf()
    fig.set_size_inches(20, 10)
    plt.subplot(4, 4, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(cat_names[index])
    
plt.show()
